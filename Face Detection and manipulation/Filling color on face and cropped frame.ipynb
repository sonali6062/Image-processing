# %%
import cv2 as cv
import numpy as np
# Load the Haar Cascade Classifier for face detection
classifier = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

# Start video capture from the default camera (webcam)
cam = cv.VideoCapture(0)

while True:
    
    # Read one frame from the camera
    _, img = cam.read()
    
    # Flip the frame horizontally (mirror effect)
    img = cv.flip(img, 1)
    
    # Detect faces in the frame (returns list of bounding boxes)
    # Parameters: scaleFactor=1.1, minNeighbors=5
    faces = classifier.detectMultiScale(img, 1.1, 5)
    
    # Loop through detected faces
    for f in faces:                             
        if f[-1] == max(faces[:,-1]):           # Choose the face with the largest area (last value = width/height)
            break 

    # If at least one face is detected
    if (len(faces) >= 1):                       
        x = f[0]    # x-coordinate of top-left corner
        y = f[1]    # y-coordinate of top-left corner
        w = f[2]    # width of bounding box
        h = f[3]    # height of bounding box

        # Draw a green rectangle around the detected face
        # cv.rectangle(img, (x,y),(x+w,y+h) , (0,180,0), 2)   
        
        # Crop the face region from the frame
        face = img[y-20:y+h+20, x:x+w]
        face=cv.blur(face,(10,10))
        img[y-20:y+h+20, x:x+w]=face 
        
        # Resize the cropped face to 256x256 pixels
        # face = cv.resize(face, (256,256))

    # Show the full video frame
    cv.imshow('Frame', img)
    
    # Show only the cropped face
    cv.imshow('Face', face)
    
    # Exit when 'Esc' key (27) is pressed
    if cv.waitKey(1) == 27:
        cam.release()  # Release the webcam
        break

# %%
np.zeros(())
# Out:
# array(0.)

# %%
face[0],face[1],face[2],face[3]
# Out:
# (array([[150, 154, 159],
#         [150, 154, 159],
#         [150, 155, 159],
#         [150, 155, 160],
#         [151, 156, 160],
#         [151, 156, 160],
#         [151, 157, 160],
#         [151, 157, 161],
#         [152, 158, 161],
#         [152, 158, 161],
#         [152, 159, 161],
#         [152, 159, 162],
#         [152, 159, 162],
#         [152, 159, 162],
#         [152, 159, 161],
#         [152, 159, 161],
#         [152, 158, 161],
#         [151, 158, 161],
#         [151, 158, 161],
#         [151, 157, 161],
#         [150, 157, 161],
#         [150, 157, 161],
#         [148, 156, 160],
#         [147, 155, 160],
#         [145, 153, 159],
#         [144, 152, 158],
#         [143, 151, 157],
#         [142, 150, 156],
#         [141, 149, 156],
#         [140, 147, 154],
#         [138, 146, 153],
#         [136, 144, 151],
#         [135, 143, 149],
#         [134, 141, 148],
#         [131, 139, 145],
#         [126, 134, 140],
#         [120, 128, 133],
#         [112, 120, 125],
#         [103, 112, 117],
#         [ 94, 103, 108],
#         [ 85,  94,  99],
#         [ 77,  86,  91],
#         [ 68,  78,  83],
#         [ 60,  70,  75],
#         [ 54,  63,  68],
#         [ 49,  58,  63],
#         [ 46,  55,  60],
#         [ 44,  53,  58],
#         [ 43,  52,  57],
#         [ 43,  51,  56],
#         [ 43,  51,  56],
#         [ 42,  51,  55],
#         [ 42,  51,  55],
#         [ 41,  51,  55],
#         [ 41,  51,  55],
#         [ 40,  51,  55],
#         [ 40,  51,  54],
#         [ 39,  50,  54],
#         [ 39,  50,  54],
#         [ 38,  49,  54],
#         [ 38,  49,  55],
#         [ 38,  49,  55],
#         [ 38,  48,  55],
#         [ 38,  48,  56],
#         [ 38,  48,  56],
#         [ 38,  48,  57],
#         [ 38,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  56],
#         [ 40,  48,  56],
#         [ 39,  48,  56],
#         [ 39,  47,  55],
#         [ 38,  47,  54],
#         [ 37,  46,  53],
#         [ 37,  46,  52],
#         [ 36,  45,  51],
#         [ 35,  45,  50],
#         [ 35,  44,  49],
#         [ 34,  44,  48],
#         [ 34,  43,  47],
#         [ 34,  42,  47],
#         [ 33,  42,  46],
#         [ 33,  41,  46],
#         [ 33,  40,  45],
#         [ 33,  40,  45],
#         [ 32,  39,  44],
#         [ 32,  38,  44],
#         [ 32,  38,  44],
#         [ 32,  37,  44],
#         [ 31,  37,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  37,  44],
#         [ 30,  37,  45],
#         [ 30,  37,  45],
#         [ 31,  38,  46],
#         [ 31,  38,  46],
#         [ 31,  39,  47],
#         [ 32,  39,  48],
#         [ 32,  40,  48],
#         [ 32,  40,  49],
#         [ 33,  41,  50],
#         [ 34,  42,  51],
#         [ 35,  43,  52],
#         [ 36,  43,  53],
#         [ 37,  44,  54],
#         [ 38,  46,  56],
#         [ 40,  47,  57],
#         [ 42,  48,  59],
#         [ 44,  49,  61],
#         [ 45,  50,  62],
#         [ 46,  52,  64],
#         [ 48,  53,  66],
#         [ 48,  53,  67],
#         [ 48,  54,  69],
#         [ 48,  55,  70],
#         [ 47,  55,  71],
#         [ 46,  55,  72],
#         [ 45,  54,  73],
#         [ 44,  54,  73],
#         [ 43,  54,  74],
#         [ 42,  54,  74],
#         [ 41,  54,  75],
#         [ 42,  55,  76],
#         [ 42,  56,  78],
#         [ 43,  57,  80],
#         [ 44,  58,  81],
#         [ 45,  59,  83],
#         [ 46,  61,  86],
#         [ 47,  63,  88],
#         [ 48,  65,  89],
#         [ 49,  66,  91],
#         [ 49,  67,  92],
#         [ 50,  68,  92],
#         [ 49,  68,  92]], dtype=uint8),
#  array([[150, 154, 159],
#         [150, 154, 159],
#         [150, 155, 159],
#         [150, 155, 160],
#         [151, 156, 160],
#         [151, 156, 160],
#         [151, 157, 160],
#         [151, 157, 161],
#         [152, 158, 161],
#         [152, 158, 161],
#         [152, 159, 161],
#         [152, 159, 162],
#         [152, 159, 162],
#         [152, 159, 162],
#         [152, 159, 161],
#         [152, 159, 161],
#         [152, 158, 161],
#         [151, 158, 161],
#         [151, 158, 161],
#         [151, 157, 161],
#         [150, 157, 161],
#         [150, 157, 161],
#         [148, 156, 160],
#         [147, 155, 160],
#         [145, 153, 159],
#         [144, 152, 158],
#         [143, 151, 157],
#         [142, 150, 156],
#         [141, 149, 156],
#         [140, 147, 154],
#         [138, 146, 153],
#         [136, 144, 151],
#         [135, 143, 149],
#         [134, 141, 148],
#         [131, 139, 145],
#         [126, 134, 140],
#         [120, 128, 133],
#         [112, 120, 125],
#         [103, 112, 117],
#         [ 94, 103, 108],
#         [ 85,  94,  99],
#         [ 77,  86,  91],
#         [ 68,  78,  83],
#         [ 60,  70,  75],
#         [ 54,  63,  68],
#         [ 49,  58,  63],
#         [ 46,  55,  60],
#         [ 44,  53,  58],
#         [ 43,  52,  57],
#         [ 43,  51,  56],
#         [ 43,  51,  56],
#         [ 42,  51,  55],
#         [ 42,  51,  55],
#         [ 41,  51,  55],
#         [ 41,  51,  55],
#         [ 40,  51,  55],
#         [ 40,  51,  54],
#         [ 39,  50,  54],
#         [ 39,  50,  54],
#         [ 38,  49,  54],
#         [ 38,  49,  55],
#         [ 38,  49,  55],
#         [ 38,  48,  55],
#         [ 38,  48,  56],
#         [ 38,  48,  56],
#         [ 38,  48,  57],
#         [ 38,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  56],
#         [ 40,  48,  56],
#         [ 39,  48,  56],
#         [ 39,  47,  55],
#         [ 38,  47,  54],
#         [ 37,  46,  53],
#         [ 37,  46,  52],
#         [ 36,  45,  51],
#         [ 35,  45,  50],
#         [ 35,  44,  49],
#         [ 34,  44,  48],
#         [ 34,  43,  47],
#         [ 34,  42,  47],
#         [ 33,  42,  46],
#         [ 33,  41,  46],
#         [ 33,  40,  45],
#         [ 33,  40,  45],
#         [ 32,  39,  44],
#         [ 32,  38,  44],
#         [ 32,  38,  44],
#         [ 32,  37,  44],
#         [ 31,  37,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  36,  44],
#         [ 30,  37,  44],
#         [ 30,  37,  45],
#         [ 30,  37,  45],
#         [ 31,  38,  46],
#         [ 31,  38,  46],
#         [ 31,  39,  47],
#         [ 32,  39,  48],
#         [ 32,  40,  48],
#         [ 32,  40,  49],
#         [ 33,  41,  50],
#         [ 34,  42,  51],
#         [ 35,  43,  52],
#         [ 36,  43,  53],
#         [ 37,  44,  54],
#         [ 38,  46,  56],
#         [ 40,  47,  57],
#         [ 42,  48,  59],
#         [ 44,  49,  61],
#         [ 45,  50,  62],
#         [ 46,  52,  64],
#         [ 48,  53,  66],
#         [ 48,  53,  67],
#         [ 48,  54,  69],
#         [ 48,  55,  70],
#         [ 47,  55,  71],
#         [ 46,  55,  72],
#         [ 45,  54,  73],
#         [ 44,  54,  73],
#         [ 43,  54,  74],
#         [ 42,  54,  74],
#         [ 41,  54,  75],
#         [ 42,  55,  76],
#         [ 42,  56,  78],
#         [ 43,  57,  80],
#         [ 44,  58,  81],
#         [ 45,  59,  83],
#         [ 46,  61,  86],
#         [ 47,  63,  88],
#         [ 48,  65,  89],
#         [ 49,  66,  91],
#         [ 49,  67,  92],
#         [ 50,  68,  92],
#         [ 49,  68,  92]], dtype=uint8),
#  array([[149, 153, 158],
#         [149, 153, 158],
#         [150, 154, 159],
#         [150, 155, 159],
#         [150, 155, 159],
#         [150, 155, 159],
#         [150, 156, 160],
#         [150, 156, 160],
#         [150, 157, 160],
#         [151, 157, 160],
#         [151, 158, 160],
#         [151, 158, 160],
#         [151, 157, 160],
#         [150, 157, 160],
#         [150, 157, 159],
#         [149, 156, 159],
#         [149, 155, 158],
#         [148, 155, 158],
#         [147, 154, 158],
#         [147, 154, 157],
#         [146, 153, 157],
#         [145, 152, 156],
#         [143, 151, 156],
#         [142, 150, 155],
#         [141, 148, 154],
#         [139, 147, 153],
#         [138, 146, 152],
#         [137, 145, 152],
#         [137, 144, 151],
#         [135, 143, 150],
#         [134, 142, 149],
#         [133, 140, 147],
#         [132, 139, 146],
#         [130, 138, 144],
#         [128, 135, 142],
#         [124, 131, 137],
#         [117, 125, 131],
#         [110, 118, 123],
#         [101, 110, 115],
#         [ 93, 102, 106],
#         [ 84,  93,  98],
#         [ 76,  86,  90],
#         [ 68,  78,  82],
#         [ 60,  70,  74],
#         [ 54,  63,  68],
#         [ 49,  58,  63],
#         [ 46,  55,  60],
#         [ 44,  53,  58],
#         [ 43,  52,  57],
#         [ 43,  51,  56],
#         [ 43,  51,  56],
#         [ 42,  51,  55],
#         [ 41,  51,  55],
#         [ 41,  51,  55],
#         [ 41,  51,  55],
#         [ 40,  51,  54],
#         [ 40,  50,  54],
#         [ 39,  50,  54],
#         [ 39,  50,  54],
#         [ 38,  49,  54],
#         [ 38,  49,  55],
#         [ 38,  48,  55],
#         [ 38,  48,  55],
#         [ 38,  48,  56],
#         [ 38,  48,  56],
#         [ 38,  48,  57],
#         [ 38,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 40,  48,  58],
#         [ 40,  48,  58],
#         [ 40,  48,  57],
#         [ 40,  49,  57],
#         [ 40,  49,  57],
#         [ 40,  48,  57],
#         [ 40,  48,  56],
#         [ 39,  48,  56],
#         [ 39,  47,  55],
#         [ 38,  47,  54],
#         [ 38,  46,  53],
#         [ 37,  46,  52],
#         [ 36,  46,  51],
#         [ 36,  45,  50],
#         [ 35,  44,  49],
#         [ 35,  44,  48],
#         [ 34,  43,  48],
#         [ 34,  43,  47],
#         [ 34,  42,  46],
#         [ 33,  41,  46],
#         [ 33,  41,  45],
#         [ 33,  40,  45],
#         [ 32,  39,  45],
#         [ 32,  39,  44],
#         [ 32,  38,  44],
#         [ 32,  38,  44],
#         [ 32,  37,  44],
#         [ 31,  37,  44],
#         [ 31,  37,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 31,  36,  44],
#         [ 31,  37,  44],
#         [ 31,  37,  44],
#         [ 30,  37,  44],
#         [ 30,  37,  45],
#         [ 31,  37,  45],
#         [ 31,  38,  45],
#         [ 31,  38,  46],
#         [ 31,  39,  46],
#         [ 31,  39,  47],
#         [ 32,  39,  48],
#         [ 32,  40,  48],
#         [ 32,  40,  49],
#         [ 33,  41,  50],
#         [ 34,  42,  51],
#         [ 35,  43,  52],
#         [ 36,  43,  53],
#         [ 37,  44,  54],
#         [ 38,  45,  55],
#         [ 40,  47,  57],
#         [ 42,  48,  58],
#         [ 43,  49,  60],
#         [ 44,  50,  61],
#         [ 46,  51,  63],
#         [ 47,  52,  65],
#         [ 47,  53,  66],
#         [ 48,  54,  68],
#         [ 47,  54,  69],
#         [ 47,  55,  71],
#         [ 46,  55,  71],
#         [ 45,  54,  72],
#         [ 44,  54,  73],
#         [ 43,  54,  73],
#         [ 42,  54,  74],
#         [ 41,  54,  74],
#         [ 41,  54,  75],
#         [ 42,  55,  77],
#         [ 42,  56,  79],
#         [ 43,  57,  80],
#         [ 44,  58,  82],
#         [ 45,  60,  84],
#         [ 47,  62,  86],
#         [ 47,  64,  88],
#         [ 48,  66,  90],
#         [ 49,  67,  91],
#         [ 50,  68,  92],
#         [ 50,  68,  92]], dtype=uint8),
#  array([[147, 152, 157],
#         [147, 152, 157],
#         [148, 152, 157],
#         [148, 153, 157],
#         [148, 153, 157],
#         [148, 153, 157],
#         [147, 153, 157],
#         [147, 153, 157],
#         [147, 154, 157],
#         [147, 154, 157],
#         [147, 154, 157],
#         [147, 154, 157],
#         [147, 154, 157],
#         [147, 153, 156],
#         [146, 153, 156],
#         [146, 152, 155],
#         [145, 152, 155],
#         [144, 151, 154],
#         [144, 150, 154],
#         [143, 150, 154],
#         [142, 149, 153],
#         [141, 148, 153],
#         [140, 147, 152],
#         [138, 146, 151],
#         [137, 145, 150],
#         [135, 143, 149],
#         [134, 142, 149],
#         [133, 141, 148],
#         [132, 140, 147],
#         [131, 138, 145],
#         [129, 137, 144],
#         [128, 135, 142],
#         [126, 134, 140],
#         [125, 132, 139],
#         [122, 129, 136],
#         [118, 125, 131],
#         [112, 120, 125],
#         [105, 113, 119],
#         [ 97, 105, 111],
#         [ 89,  98, 103],
#         [ 81,  90,  95],
#         [ 74,  83,  88],
#         [ 66,  76,  80],
#         [ 59,  68,  73],
#         [ 53,  62,  67],
#         [ 49,  58,  63],
#         [ 46,  54,  60],
#         [ 44,  52,  57],
#         [ 43,  51,  56],
#         [ 43,  51,  56],
#         [ 42,  51,  56],
#         [ 42,  50,  55],
#         [ 41,  50,  54],
#         [ 41,  50,  54],
#         [ 40,  50,  54],
#         [ 40,  50,  54],
#         [ 39,  50,  54],
#         [ 39,  50,  54],
#         [ 39,  49,  54],
#         [ 38,  49,  54],
#         [ 38,  49,  54],
#         [ 38,  48,  55],
#         [ 38,  48,  55],
#         [ 38,  48,  56],
#         [ 39,  48,  56],
#         [ 39,  48,  57],
#         [ 39,  48,  57],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 38,  48,  58],
#         [ 38,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  48,  58],
#         [ 39,  49,  58],
#         [ 40,  49,  58],
#         [ 40,  49,  58],
#         [ 40,  49,  57],
#         [ 40,  49,  57],
#         [ 40,  49,  57],
#         [ 40,  48,  56],
#         [ 39,  48,  56],
#         [ 39,  48,  55],
#         [ 38,  47,  54],
#         [ 38,  47,  53],
#         [ 37,  46,  52],
#         [ 37,  46,  51],
#         [ 36,  45,  50],
#         [ 35,  45,  49],
#         [ 35,  44,  49],
#         [ 35,  44,  48],
#         [ 35,  43,  47],
#         [ 34,  42,  47],
#         [ 34,  42,  46],
#         [ 34,  41,  46],
#         [ 33,  41,  45],
#         [ 33,  40,  45],
#         [ 33,  39,  45],
#         [ 33,  39,  45],
#         [ 33,  38,  45],
#         [ 32,  38,  45],
#         [ 32,  38,  45],
#         [ 32,  38,  45],
#         [ 32,  37,  45],
#         [ 32,  37,  45],
#         [ 32,  37,  45],
#         [ 32,  37,  45],
#         [ 32,  37,  45],
#         [ 31,  37,  45],
#         [ 31,  38,  45],
#         [ 31,  38,  45],
#         [ 31,  38,  46],
#         [ 31,  38,  46],
#         [ 32,  39,  46],
#         [ 32,  39,  47],
#         [ 32,  39,  47],
#         [ 32,  40,  48],
#         [ 32,  40,  49],
#         [ 33,  41,  49],
#         [ 33,  41,  50],
#         [ 34,  42,  51],
#         [ 35,  43,  52],
#         [ 36,  43,  53],
#         [ 37,  44,  53],
#         [ 38,  45,  54],
#         [ 39,  46,  56],
#         [ 41,  47,  57],
#         [ 42,  48,  58],
#         [ 43,  49,  60],
#         [ 45,  50,  61],
#         [ 46,  51,  63],
#         [ 46,  52,  64],
#         [ 47,  53,  66],
#         [ 47,  53,  68],
#         [ 46,  54,  69],
#         [ 46,  54,  70],
#         [ 45,  54,  71],
#         [ 44,  54,  72],
#         [ 44,  54,  73],
#         [ 43,  54,  73],
#         [ 42,  54,  74],
#         [ 42,  54,  75],
#         [ 42,  55,  76],
#         [ 43,  56,  78],
#         [ 44,  57,  80],
#         [ 46,  59,  82],
#         [ 48,  62,  85],
#         [ 50,  65,  88],
#         [ 51,  67,  91],
#         [ 53,  70,  93],
#         [ 55,  72,  96],
#         [ 57,  74,  98],
#         [ 57,  75,  98]], dtype=uint8))

# %%
face.shape
# Out:
# (194, 154, 3)

# %%
import cv2 as cv
import numpy as np

classifier = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
cam = cv.VideoCapture(0)

while True:
    
    _, img = cam.read()
    img = cv.flip(img,1)
    
    faces = classifier.detectMultiScale(img, 1.1, 5)
    
    for f in faces:
        if f[-1] == max(faces[:,-1]):
            break

    x = f[0] 
    y = f[1] 
    w = f[2]
    h = f[3]

    face = img[y:y+h, x:x+w]
    
    black = np.zeros((face.shape), dtype = int)
    
    img[y:y+h, x:x+w] = (255,0,0)
    

    cv.imshow('Frame'  , img )
    cv.imshow('Face'   , face)
    
    if cv.waitKey(1) == 27:
        cam.release()
        break

# %% [markdown]
# # Creating circle

# %%
w,h

# %%
import cv2 as cv
import numpy as np

classifier = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
cam = cv.VideoCapture(0)

while True:
    ret, img = cam.read()
    if not ret:
        break

    img = cv.flip(img, 1)

    faces = classifier.detectMultiScale(img, 1.1, 5)

    if len(faces) > 0:
        # Pick the largest face
        f = max(faces, key=lambda rect: rect[2]*rect[3])
        x, y, w, h = f

        # Draw a colored circle over the face
        circle_x = x + w // 2
        circle_y = y + h // 2
        cv.circle(img, (circle_x, circle_y), int(w/1.7), (255, 55, 180), -1)

        # Crop the face region
        face_crop = img[y:y+h, x:x+w].copy()

        # Fill the cropped face with solid color (for visualization)
        colored_face = np.full_like(face_crop, (255, 55, 180))  # Red color

        # Show the colored face separately
        cv.imshow("Colored Face", colored_face)

    # Show full frame with circle overlay
    cv.imshow("Frame", img)

    if cv.waitKey(1) == 27:
        break

cam.release()
cv.destroyAllWindows()
