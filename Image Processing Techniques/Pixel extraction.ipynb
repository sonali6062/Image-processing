# %%
import cv2 as cv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading an image using OpenCV

# %%
img=cv.imread("Transition of colors.jpg")
plt.imshow(img)

# %% [markdown]
# # Converting RGB to BGR

# %%
img=cv.cvtColor(img,cv.COLOR_RGB2BGR)
plt.imshow(img)

# %% [markdown]
# OBSERVATION- Frames got interchanged

# %% [markdown]
# # Frame Extraction

# %%
img.shape

# %%
img[:1000,:,:]

# %%
img[:500,:,:].shape

# %%
plt.imshow(img[:,500:1000,:])

# %%
plt.imshow(img[:500,:,:])

# %%
plt.imshow(img[500:1000,:,:])

# %%
plt.imshow(img[1000:1500,:,:])

# %% [markdown]
# # Frame Extraction

# %%
r=img[:,:,0]#red
g=img[:,:,1]#green
b=img[:,:,2]#blue

# %%
plt.imshow(r)
#displays only the area containing red

# %%
img=cv.cvtColor(r,cv.COLOR_RGB2BGR)
plt.imshow(img)

# %%
plt.imshow(g)
#displays only the area containing green

# %%
img=cv.cvtColor(g,cv.COLOR_RGB2BGR)
plt.imshow(img)

# %%
plt.imshow(b)
#displays only the area containing blue

# %%
img=cv.cvtColor(b,cv.COLOR_RGB2BGR)
plt.imshow(img)

# %%
cv.imwrite("red.jpg",r)
cv.imwrite("green.jpg",g)
cv.imwrite("blue.jpg",b)
